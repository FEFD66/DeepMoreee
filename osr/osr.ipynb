# %%
import datetime
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import lr_scheduler
import torch.multiprocessing as mp
import torch.backends.cudnn as cudnn

from datasets.osr_dataloader import MNIST_OSR
from models import gan
from models.models import classifier32, classifier32ABN
from utils import Logger, save_networks, load_networks
from core import train, train_cs, test

# %%
seed = 0
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
device="gpu:0"
data_root = "../data/mnist"

# %%
known = [2, 4, 5, 9, 8, 3]
unknown = list(set(list(range(0, 10))) - set(known))
batch_size=128
img_size= 32
Data = MNIST_OSR(known,data_root)
trainloader,testloader,outloader = Data.train_loader,Data.test_loader,Data.out_loader
# Out:
# Selected Labels:  [2, 4, 5, 9, 8, 3]
# All Train Data: 60000
# All Test Data: 10000
# Train:  35152 Test:  5899 Out:  4101
# All Test:  10000

# %%
# net = classifier32(num_classes=Data.num_classes)
net = classifier32ABN(num_classes=Data.num_classes)
net=nn.DataParallel(net).cuda()

# %%
# GAN
nz,ns=100,1
netG = gan.Generator32(1, nz, 64, 3)
netD = gan.Discriminator32(1, 3, 64)
fixed_noise = torch.FloatTensor(64, nz, 1, 1).normal_(0, 1)

netG = nn.DataParallel(netG).cuda()
netD = nn.DataParallel(netD).cuda()
fixed_noise=fixed_noise.cuda()

# %%
import loss.ARPLoss as Loss
criterion = Loss.ARPLoss(num_classes=Data.num_classes)
criterion=criterion.cuda()

criterionD = nn.BCELoss()

# %%
eval = False
model_path="E:\osr"
file_name= "parm"

# %%
if eval:
    net, criterion = load_networks(net, model_path, file_name, criterion=criterion)
    results = test(net, criterion, testloader, outloader, epoch=0)
    print("Acc (%): {:.3f}\t AUROC (%): {:.3f}\t OSCR (%): {:.3f}\t"
      .format(results['ACC'], results['AUROC'], results['OSCR']))

# %%
lr=0.1
gan_lr=0.0002
params_list = [{'params': net.parameters()},
                {'params': criterion.parameters()}]
optimizer = torch.optim.SGD(params_list, lr, momentum=0.9, weight_decay=1e-4)
# GAN
optimizerD = torch.optim.Adam(netD.parameters(), lr=gan_lr, betas=(0.5, 0.999))
optimizerG = torch.optim.Adam(netG.parameters(), lr=gan_lr, betas=(0.5, 0.999))

scheduler = lr_scheduler.MultiStepLR(optimizer, milestones=[30,60,90,120])

# %%
start_time = time.time()
max_epoch=20
eval_freq=1
print_freq=100
for epoch in range(max_epoch):
    print("==> Epoch {}/{}".format(epoch+1, max_epoch))

    # if options['cs']:
    train_cs(net, netD, netG, criterion, criterionD,
                optimizer, optimizerD, optimizerG,
                trainloader,nz,ns,print_freq,beta=0.1, epoch=epoch)
    #     train_cs(net, netD, netG, criterion, criterionD,
    #         optimizer, optimizerD, optimizerG,
    #         trainloader, epoch=epoch, **options)

    train(net, criterion, optimizer, trainloader, epoch=epoch,print_freq=print_freq)

    if eval_freq > 0 and (epoch+1) % eval_freq == 0 or (epoch+1) == max_epoch:
        print("==> Test", "ARPLoss")
        results = test(net, criterion, testloader, outloader, epoch=epoch)
        print("Acc (%): {:.3f}\t AUROC (%): {:.3f}\t OSCR (%): {:.3f}\t".format(results['ACC'], results['AUROC'], results['OSCR']))

        save_networks(net, model_path, file_name, criterion=criterion)

    if 30 > 0: scheduler.step()

elapsed = round(time.time() - start_time)
elapsed = str(datetime.timedelta(seconds=elapsed))
print("Finished. Total elapsed time (h:m:s): {}".format(elapsed))
# Out:
# ==> Epoch 1/20
# train with confusing samples
# Batch 100/550	 Net 0.209 (0.647) G 5.394 (6.025) D 0.042 (0.169)
# Batch 200/550	 Net 0.212 (0.417) G 1.761 (5.487) D 0.756 (0.283)
# Batch 300/550	 Net 0.130 (0.319) G 2.691 (4.772) D 0.421 (0.401)
# Batch 400/550	 Net 0.042 (0.266) G 1.287 (4.329) D 0.924 (0.458)
# Batch 500/550	 Net 0.112 (0.234) G 2.048 (4.004) D 0.479 (0.498)
# Batch 100/550	 Loss 0.056042 (0.070950)
# Batch 200/550	 Loss 0.009324 (0.066400)
# Batch 300/550	 Loss 0.161371 (0.068910)
# Batch 400/550	 Loss 0.011236 (0.066773)
# Batch 500/550	 Loss 0.021558 (0.063934)
# ==> Test ARPLoss
# Acc: 98.93202
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    81.078 96.246 91.265 97.637 92.096
# Acc (%): 98.932	 AUROC (%): 96.246	 OSCR (%): 95.608
# ==> Epoch 2/20
# train with confusing samples
# Batch 100/550	 Net 0.066 (0.071) G 3.882 (2.346) D 1.100 (0.761)
# Batch 200/550	 Net 0.076 (0.071) G 0.724 (2.302) D 1.447 (0.769)
# Batch 300/550	 Net 0.079 (0.070) G 2.158 (2.290) D 0.694 (0.776)
# Batch 400/550	 Net 0.026 (0.068) G 2.112 (2.270) D 0.718 (0.783)
# Batch 500/550	 Net 0.022 (0.068) G 2.163 (2.273) D 0.640 (0.779)
# Batch 100/550	 Loss 0.020008 (0.044692)
# Batch 200/550	 Loss 0.148968 (0.047581)
# Batch 300/550	 Loss 0.085226 (0.046899)
# Batch 400/550	 Loss 0.007416 (0.045265)
# Batch 500/550	 Loss 0.085011 (0.044542)
# ==> Test ARPLoss
# Acc: 99.13545
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    90.953 97.930 93.438 98.680 96.159
# Acc (%): 99.135	 AUROC (%): 97.930	 OSCR (%): 97.301
# ==> Epoch 3/20
# train with confusing samples
# Batch 100/550	 Net 0.057 (0.053) G 2.008 (2.532) D 0.566 (0.734)
# Batch 200/550	 Net 0.087 (0.054) G 3.227 (2.647) D 0.477 (0.709)
# Batch 300/550	 Net 0.146 (0.055) G 3.442 (2.660) D 0.346 (0.714)
# Batch 400/550	 Net 0.022 (0.054) G 2.250 (2.755) D 0.446 (0.695)
# Batch 500/550	 Net 0.064 (0.054) G 3.178 (2.838) D 0.420 (0.662)
# Batch 100/550	 Loss 0.019471 (0.039854)
# Batch 200/550	 Loss 0.088285 (0.035253)
# Batch 300/550	 Loss 0.040940 (0.038612)
# Batch 400/550	 Loss 0.009540 (0.037745)
# Batch 500/550	 Loss 0.008300 (0.036708)
# ==> Test ARPLoss
# Acc: 99.28801
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    95.830 98.865 95.459 99.280 97.931
# Acc (%): 99.288	 AUROC (%): 98.865	 OSCR (%): 98.349
# ==> Epoch 4/20
# train with confusing samples
# Batch 100/550	 Net 0.019 (0.045) G 2.219 (2.501) D 0.690 (0.774)
# Batch 200/550	 Net 0.019 (0.049) G 4.439 (3.093) D 0.074 (0.540)
# Batch 300/550	 Net 0.032 (0.049) G 0.829 (2.664) D 0.751 (0.730)
# Batch 400/550	 Net 0.021 (0.049) G 2.473 (2.662) D 0.646 (0.721)
# Batch 500/550	 Net 0.020 (0.050) G 4.110 (2.756) D 0.124 (0.691)
# Batch 100/550	 Loss 0.006275 (0.029808)
# Batch 200/550	 Loss 0.040382 (0.030653)
# Batch 300/550	 Loss 0.051018 (0.032212)
# Batch 400/550	 Loss 0.036497 (0.031890)
# Batch 500/550	 Loss 0.002231 (0.032066)
# ==> Test ARPLoss
# Acc: 99.44058
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    94.343 98.395 94.683 98.969 97.165
# Acc (%): 99.441	 AUROC (%): 98.395	 OSCR (%): 97.997
# ==> Epoch 5/20
# train with confusing samples
# Batch 100/550	 Net 0.017 (0.050) G 3.542 (3.016) D 0.292 (0.730)
# Batch 200/550	 Net 0.021 (0.048) G 4.425 (3.216) D 0.069 (0.602)
# Batch 300/550	 Net 0.067 (0.049) G 5.137 (3.795) D 0.051 (0.422)
# Batch 400/550	 Net 0.129 (0.048) G 2.057 (3.787) D 0.880 (0.472)
# Batch 500/550	 Net 0.048 (0.048) G 1.461 (3.410) D 0.839 (0.551)
# Batch 100/550	 Loss 0.031091 (0.032819)
# Batch 200/550	 Loss 0.034615 (0.031674)
# Batch 300/550	 Loss 0.001755 (0.030535)
# Batch 400/550	 Loss 0.004291 (0.030021)
# Batch 500/550	 Loss 0.073725 (0.029230)
# ==> Test ARPLoss
# Acc: 99.28801
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    95.026 98.417 95.097 99.005 97.076
# Acc (%): 99.288	 AUROC (%): 98.417	 OSCR (%): 97.933
# ==> Epoch 6/20
# train with confusing samples
# Batch 100/550	 Net 0.081 (0.044) G 3.845 (2.420) D 0.824 (0.729)
# Batch 200/550	 Net 0.039 (0.046) G 1.318 (2.669) D 2.503 (0.720)
# Batch 300/550	 Net 0.056 (0.047) G 1.856 (2.625) D 0.763 (0.736)
# Batch 400/550	 Net 0.063 (0.048) G 4.842 (2.803) D 0.075 (0.661)
# Batch 500/550	 Net 0.020 (0.047) G 5.366 (3.272) D 0.042 (0.538)
# Batch 100/550	 Loss 0.031520 (0.035462)
# Batch 200/550	 Loss 0.027307 (0.031473)
# Batch 300/550	 Loss 0.038551 (0.030866)
# Batch 400/550	 Loss 0.028712 (0.030021)
# Batch 500/550	 Loss 0.008199 (0.030027)
# ==> Test ARPLoss
# Acc: 99.42363
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    94.952 98.883 95.071 99.266 98.126
# Acc (%): 99.424	 AUROC (%): 98.883	 OSCR (%): 98.459
# ==> Epoch 7/20
# train with confusing samples
# Batch 100/550	 Net 0.059 (0.040) G 6.073 (5.899) D 0.012 (0.022)
# Batch 200/550	 Net 0.021 (0.040) G 1.731 (5.779) D 0.831 (0.163)
# Batch 300/550	 Net 0.019 (0.041) G 2.817 (4.619) D 0.474 (0.347)
# Batch 400/550	 Net 0.038 (0.040) G 3.547 (4.182) D 0.652 (0.413)
# Batch 500/550	 Net 0.063 (0.041) G 1.568 (3.920) D 0.906 (0.465)
# Batch 100/550	 Loss 0.004269 (0.025763)
# Batch 200/550	 Loss 0.000339 (0.022738)
# Batch 300/550	 Loss 0.026810 (0.024879)
# Batch 400/550	 Loss 0.047747 (0.025888)
# Batch 500/550	 Loss 0.036733 (0.027126)
# ==> Test ARPLoss
# Acc: 99.49144
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    93.636 98.382 94.627 99.035 96.857
# Acc (%): 99.491	 AUROC (%): 98.382	 OSCR (%): 98.070
# ==> Epoch 8/20
# train with confusing samples
# Batch 100/550	 Net 0.093 (0.041) G 4.677 (3.127) D 0.193 (0.631)
# Batch 200/550	 Net 0.018 (0.041) G 5.739 (4.215) D 0.016 (0.346)
# Batch 300/550	 Net 0.025 (0.042) G 5.887 (4.817) D 0.025 (0.239)
# Batch 400/550	 Net 0.019 (0.042) G 6.937 (5.230) D 0.008 (0.184)
# Batch 500/550	 Net 0.024 (0.044) G 1.446 (5.434) D 0.770 (0.260)
# Batch 100/550	 Loss 0.003953 (0.023374)
# Batch 200/550	 Loss 0.047923 (0.024111)
# Batch 300/550	 Loss 0.097928 (0.024681)
# Batch 400/550	 Loss 0.012689 (0.024676)
# Batch 500/550	 Loss 0.010347 (0.024483)
# ==> Test ARPLoss
# Acc: 99.32192
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    95.782 98.959 95.433 99.293 98.364
# Acc (%): 99.322	 AUROC (%): 98.959	 OSCR (%): 98.418
# ==> Epoch 9/20
# train with confusing samples
# Batch 100/550	 Net 0.018 (0.039) G 1.530 (3.304) D 0.553 (0.489)
# Batch 200/550	 Net 0.021 (0.041) G 4.309 (3.202) D 0.158 (0.585)
# Batch 300/550	 Net 0.022 (0.042) G 1.457 (3.483) D 0.681 (0.581)
# Batch 400/550	 Net 0.041 (0.041) G 3.440 (3.419) D 0.285 (0.568)
# Batch 500/550	 Net 0.019 (0.043) G 2.514 (3.391) D 0.367 (0.566)
# Batch 100/550	 Loss 0.040171 (0.026012)
# Batch 200/550	 Loss 0.064752 (0.026220)
# Batch 300/550	 Loss 0.003533 (0.025863)
# Batch 400/550	 Loss 0.046803 (0.026918)
# Batch 500/550	 Loss 0.015727 (0.028068)
# ==> Test ARPLoss
# Acc: 99.62706
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    98.098 99.397 96.631 99.607 99.036
# Acc (%): 99.627	 AUROC (%): 99.397	 OSCR (%): 99.074
# ==> Epoch 10/20
# train with confusing samples
# Batch 100/550	 Net 0.019 (0.043) G 4.875 (4.204) D 0.036 (0.254)
# Batch 200/550	 Net 0.018 (0.041) G 6.884 (4.944) D 0.011 (0.139)
# Batch 300/550	 Net 0.025 (0.040) G 5.754 (5.354) D 0.021 (0.098)
# Batch 400/550	 Net 0.061 (0.041) G 6.759 (5.641) D 0.008 (0.077)
# Batch 500/550	 Net 0.086 (0.041) G 7.155 (5.868) D 0.012 (0.063)
# Batch 100/550	 Loss 0.009121 (0.026133)
# Batch 200/550	 Loss 0.028959 (0.023960)
# Batch 300/550	 Loss 0.003339 (0.022631)
# Batch 400/550	 Loss 0.040814 (0.024221)
# Batch 500/550	 Loss 0.026616 (0.024478)
# ==> Test ARPLoss
# Acc: 99.54230
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    96.708 99.097 95.994 99.409 98.509
# Acc (%): 99.542	 AUROC (%): 99.097	 OSCR (%): 98.790
# ==> Epoch 11/20
# train with confusing samples
# Batch 100/550	 Net 0.019 (0.039) G 6.801 (7.000) D 0.006 (0.006)
# Batch 200/550	 Net 0.104 (0.041) G 8.110 (7.168) D 0.006 (0.006)
# Batch 300/550	 Net 0.046 (0.042) G 7.197 (7.225) D 0.006 (0.006)
# Batch 400/550	 Net 0.049 (0.043) G 1.468 (5.989) D 0.683 (0.293)
# Batch 500/550	 Net 0.046 (0.042) G 2.218 (5.262) D 0.403 (0.363)
# Batch 100/550	 Loss 0.003533 (0.024903)
# Batch 200/550	 Loss 0.000295 (0.023371)
# Batch 300/550	 Loss 0.038374 (0.026907)
# Batch 400/550	 Loss 0.012634 (0.026793)
# Batch 500/550	 Loss 0.079654 (0.027302)
# ==> Test ARPLoss
# Acc: 99.35582
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    94.855 98.547 95.175 99.095 97.342
# Acc (%): 99.356	 AUROC (%): 98.547	 OSCR (%): 98.055
# ==> Epoch 12/20
# train with confusing samples
# Batch 100/550	 Net 0.017 (0.040) G 2.549 (2.743) D 0.583 (0.622)
# Batch 200/550	 Net 0.075 (0.041) G 3.103 (2.868) D 0.590 (0.597)
# Batch 300/550	 Net 0.042 (0.040) G 4.463 (2.935) D 0.436 (0.588)
# Batch 400/550	 Net 0.023 (0.042) G 4.027 (2.976) D 1.869 (0.597)
# Batch 500/550	 Net 0.050 (0.042) G 5.390 (2.986) D 0.802 (0.604)
# Batch 100/550	 Loss 0.019981 (0.027706)
# Batch 200/550	 Loss 0.067794 (0.026170)
# Batch 300/550	 Loss 0.043291 (0.025383)
# Batch 400/550	 Loss 0.001171 (0.024175)
# Batch 500/550	 Loss 0.059915 (0.025221)
# ==> Test ARPLoss
# Acc: 99.40668
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    96.830 98.987 95.997 99.377 98.068
# Acc (%): 99.407	 AUROC (%): 98.987	 OSCR (%): 98.513
# ==> Epoch 13/20
# train with confusing samples
# Batch 100/550	 Net 0.022 (0.055) G 2.741 (2.959) D 0.626 (0.625)
# Batch 200/550	 Net 0.052 (0.050) G 3.712 (3.149) D 0.241 (0.558)
# Batch 300/550	 Net 0.020 (0.047) G 2.567 (3.248) D 0.773 (0.565)
# Batch 400/550	 Net 0.018 (0.046) G 5.668 (3.543) D 0.031 (0.484)
# Batch 500/550	 Net 0.050 (0.045) G 7.365 (4.097) D 0.010 (0.390)
# Batch 100/550	 Loss 0.004425 (0.022500)
# Batch 200/550	 Loss 0.000607 (0.021715)
# Batch 300/550	 Loss 0.001781 (0.021799)
# Batch 400/550	 Loss 0.002905 (0.021995)
# Batch 500/550	 Loss 0.015492 (0.022553)
# ==> Test ARPLoss
# Acc: 99.22021
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    93.611 98.659 94.837 99.179 97.610
# Acc (%): 99.220	 AUROC (%): 98.659	 OSCR (%): 98.033
# ==> Epoch 14/20
# train with confusing samples
# Batch 100/550	 Net 0.057 (0.047) G 2.064 (3.958) D 0.560 (0.620)
# Batch 200/550	 Net 0.036 (0.042) G 2.309 (3.480) D 0.521 (0.594)
# Batch 300/550	 Net 0.018 (0.043) G 3.521 (3.391) D 0.397 (0.590)
# Batch 400/550	 Net 0.048 (0.043) G 3.761 (3.401) D 0.244 (0.575)
# Batch 500/550	 Net 0.025 (0.042) G 4.725 (3.472) D 0.111 (0.554)
# Batch 100/550	 Loss 0.051997 (0.025450)
# Batch 200/550	 Loss 0.004374 (0.025502)
# Batch 300/550	 Loss 0.007312 (0.023857)
# Batch 400/550	 Loss 0.032221 (0.023597)
# Batch 500/550	 Loss 0.032780 (0.024318)
# ==> Test ARPLoss
# Acc: 99.27106
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    96.708 99.295 96.015 99.537 98.909
# Acc (%): 99.271	 AUROC (%): 99.295	 OSCR (%): 98.677
# ==> Epoch 15/20
# train with confusing samples
# Batch 100/550	 Net 0.054 (0.040) G 5.647 (4.128) D 0.053 (0.322)
# Batch 200/550	 Net 0.028 (0.040) G 6.680 (5.140) D 0.006 (0.171)
# Batch 300/550	 Net 0.024 (0.038) G 7.699 (5.668) D 0.006 (0.118)
# Batch 400/550	 Net 0.022 (0.038) G 6.604 (6.061) D 0.006 (0.091)
# Batch 500/550	 Net 0.019 (0.038) G 8.660 (6.326) D 0.002 (0.074)
# Batch 100/550	 Loss 0.001481 (0.022081)
# Batch 200/550	 Loss 0.000517 (0.021742)
# Batch 300/550	 Loss 0.004326 (0.022374)
# Batch 400/550	 Loss 0.113417 (0.023666)
# Batch 500/550	 Loss 0.003619 (0.024781)
# ==> Test ARPLoss
# Acc: 99.57620
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    98.074 99.370 96.719 99.615 98.747
# Acc (%): 99.576	 AUROC (%): 99.370	 OSCR (%): 99.029
# ==> Epoch 16/20
# train with confusing samples
# Batch 100/550	 Net 0.060 (0.040) G 8.042 (7.785) D 0.002 (0.004)
# Batch 200/550	 Net 0.061 (0.042) G 7.631 (7.784) D 0.003 (0.005)
# Batch 300/550	 Net 0.051 (0.043) G 8.250 (7.828) D 0.004 (0.004)
# Batch 400/550	 Net 0.048 (0.043) G 8.690 (7.881) D 0.002 (0.004)
# Batch 500/550	 Net 0.018 (0.042) G 9.276 (7.986) D 0.001 (0.004)
# Batch 100/550	 Loss 0.003768 (0.020915)
# Batch 200/550	 Loss 0.002854 (0.022600)
# Batch 300/550	 Loss 0.038019 (0.024268)
# Batch 400/550	 Loss 0.038259 (0.024356)
# Batch 500/550	 Loss 0.000604 (0.023176)
# ==> Test ARPLoss
# Acc: 99.40668
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    97.391 99.210 96.475 99.489 98.618
# Acc (%): 99.407	 AUROC (%): 99.210	 OSCR (%): 98.728
# ==> Epoch 17/20
# train with confusing samples
# Batch 100/550	 Net 0.063 (0.036) G 8.201 (8.580) D 0.002 (0.002)
# Batch 200/550	 Net 0.027 (0.037) G 8.068 (8.606) D 0.002 (0.002)
# Batch 300/550	 Net 0.018 (0.038) G 0.017 (7.423) D 100.000 (13.683)
# Batch 400/550	 Net 0.024 (0.039) G 0.017 (5.571) D 100.000 (35.262)
# Batch 500/550	 Net 0.058 (0.039) G 0.017 (4.460) D 100.000 (48.210)
# Batch 100/550	 Loss 0.051572 (0.025322)
# Batch 200/550	 Loss 0.004160 (0.022655)
# Batch 300/550	 Loss 0.003049 (0.023524)
# Batch 400/550	 Loss 0.057092 (0.024173)
# Batch 500/550	 Loss 0.025395 (0.024458)
# ==> Test ARPLoss
# Acc: 99.52534
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    94.343 98.722 94.693 99.160 97.976
# Acc (%): 99.525	 AUROC (%): 98.722	 OSCR (%): 98.355
# ==> Epoch 18/20
# train with confusing samples
# Batch 100/550	 Net 0.017 (0.038) G 0.017 (0.017) D 100.000 (100.000)
# Batch 200/550	 Net 0.050 (0.038) G 0.017 (0.017) D 100.000 (100.000)
# Batch 300/550	 Net 0.079 (0.039) G 0.017 (0.017) D 100.000 (100.000)
# Batch 400/550	 Net 0.017 (0.040) G 0.017 (0.017) D 100.000 (100.000)
# Batch 500/550	 Net 0.020 (0.041) G 0.017 (0.017) D 100.000 (100.000)
# Batch 100/550	 Loss 0.028675 (0.020448)
# Batch 200/550	 Loss 0.001109 (0.021532)
# Batch 300/550	 Loss 0.001555 (0.021165)
# Batch 400/550	 Loss 0.002444 (0.021595)
# Batch 500/550	 Loss 0.036897 (0.021273)
# ==> Test ARPLoss
# Acc: 99.45754
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    96.367 99.036 95.743 99.376 98.430
# Acc (%): 99.458	 AUROC (%): 99.036	 OSCR (%): 98.636
# ==> Epoch 19/20
# train with confusing samples
# Batch 100/550	 Net 0.018 (0.041) G 0.017 (0.017) D 100.000 (100.000)
# Batch 200/550	 Net 0.046 (0.040) G 0.017 (0.017) D 100.000 (100.000)
# Batch 300/550	 Net 0.018 (0.039) G 0.017 (0.017) D 100.000 (100.000)
# Batch 400/550	 Net 0.050 (0.038) G 0.017 (0.017) D 100.000 (100.000)
# Batch 500/550	 Net 0.052 (0.038) G 0.017 (0.017) D 100.000 (100.000)
# Batch 100/550	 Loss 0.000966 (0.028670)
# Batch 200/550	 Loss 0.002932 (0.024754)
# Batch 300/550	 Loss 0.001261 (0.024809)
# Batch 400/550	 Loss 0.036213 (0.025235)
# Batch 500/550	 Loss 0.008377 (0.024991)
# ==> Test ARPLoss
# Acc: 99.33887
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    95.830 98.838 95.489 99.250 98.004
# Acc (%): 99.339	 AUROC (%): 98.838	 OSCR (%): 98.376
# ==> Epoch 20/20
# train with confusing samples
# Batch 100/550	 Net 0.022 (0.047) G 0.017 (0.017) D 100.000 (100.000)
# Batch 200/550	 Net 0.055 (0.042) G 0.017 (0.017) D 100.000 (100.000)
# Batch 300/550	 Net 0.021 (0.042) G 0.017 (0.017) D 100.000 (100.000)
# Batch 400/550	 Net 0.079 (0.042) G 0.017 (0.017) D 100.000 (100.000)
# Batch 500/550	 Net 0.018 (0.043) G 0.017 (0.017) D 100.000 (100.000)
# Batch 100/550	 Loss 0.003963 (0.027663)
# Batch 200/550	 Loss 0.037251 (0.027673)
# Batch 300/550	 Loss 0.000615 (0.025453)
# Batch 400/550	 Loss 0.000555 (0.025102)
# Batch 500/550	 Loss 0.067932 (0.025296)
# ==> Test ARPLoss
# Acc: 99.40668
#        TNR    AUROC  DTACC  AUIN   AUOUT
# Bas    96.635 98.948 95.932 99.356 97.831
# Acc (%): 99.407	 AUROC (%): 98.948	 OSCR (%): 98.515
# Finished. Total elapsed time (h:m:s): 1:28:10
